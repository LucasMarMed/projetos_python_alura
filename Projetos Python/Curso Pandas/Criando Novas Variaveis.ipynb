# %% [markdown]
# # Relatorio de Analise VI
# ## Criando Novas Variaveis

# %%
import pandas as pd
dados = pd.read_csv('dados/aluguel_residencial.csv', sep=';')

# %%
dados
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento              Cachambi        2      0       0    50
# ...            ...                   ...      ...    ...     ...   ...
# 21821  Apartamento                 Méier        2      0       0    70
# 21822    Quitinete                Centro        0      0       0    27
# 21823  Apartamento           Jacarepaguá        3      1       2    78
# 21824  Apartamento  São Francisco Xavier        2      1       0    48
# 21825  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 0      1700.0       500.0  60.0
# 1      7000.0         0.0   0.0
# 2       800.0       390.0  20.0
# 3       800.0       230.0   0.0
# 4      1300.0       301.0  17.0
# ...       ...         ...   ...
# 21821   900.0       490.0  48.0
# 21822   800.0       350.0  25.0
# 21823  1800.0       800.0  40.0
# 21824  1400.0       509.0  37.0
# 21825  3000.0       760.0   0.0
#
# [21826 rows x 9 columns]

# %%
dados['Valor Bruto'] = dados['Valor'] + dados['Condominio'] + dados['IPTU']
dados
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento              Cachambi        2      0       0    50
# ...            ...                   ...      ...    ...     ...   ...
# 21821  Apartamento                 Méier        2      0       0    70
# 21822    Quitinete                Centro        0      0       0    27
# 21823  Apartamento           Jacarepaguá        3      1       2    78
# 21824  Apartamento  São Francisco Xavier        2      1       0    48
# 21825  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU  Valor m2  Valor Bruto m2 Tipo Agregado  \
# 0      1700.0       500.0  60.0     42.50           56.50   Apartamento
# 1      7000.0         0.0   0.0     70.00           70.00          Casa
# 2       800.0       390.0  20.0     53.33           80.67   Apartamento
# 3       800.0       230.0   0.0     16.67           21.46   Apartamento
# 4      1300.0       301.0  17.0     26.00           32.36   Apartamento
# ...       ...         ...   ...       ...             ...           ...
# 21821   900.0       490.0  48.0     12.86           20.54   Apartamento
# 21822   800.0       350.0  25.0     29.63           43.52   Apartamento
# 21823  1800.0       800.0  40.0     23.08           33.85   Apartamento
# 21824  1400.0       509.0  37.0     29.17           40.54   Apartamento
# 21825  3000.0       760.0   0.0     42.86           53.71   Apartamento
#
#        Valor Bruto
# 0           2260.0
# 1           7000.0
# 2           1210.0
# 3           1030.0
# 4           1618.0
# ...            ...
# 21821       1438.0
# 21822       1175.0
# 21823       2640.0
# 21824       1946.0
# 21825       3760.0
#
# [21826 rows x 13 columns]

# %%
dados['Valor m2'] = dados['Valor'] / dados['Area']
dados
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento              Cachambi        2      0       0    50
# ...            ...                   ...      ...    ...     ...   ...
# 21821  Apartamento                 Méier        2      0       0    70
# 21822    Quitinete                Centro        0      0       0    27
# 21823  Apartamento           Jacarepaguá        3      1       2    78
# 21824  Apartamento  São Francisco Xavier        2      1       0    48
# 21825  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU  Valor Bruto   Valor m2
# 0      1700.0       500.0  60.0       2260.0  42.500000
# 1      7000.0         0.0   0.0       7000.0  70.000000
# 2       800.0       390.0  20.0       1210.0  53.333333
# 3       800.0       230.0   0.0       1030.0  16.666667
# 4      1300.0       301.0  17.0       1618.0  26.000000
# ...       ...         ...   ...          ...        ...
# 21821   900.0       490.0  48.0       1438.0  12.857143
# 21822   800.0       350.0  25.0       1175.0  29.629630
# 21823  1800.0       800.0  40.0       2640.0  23.076923
# 21824  1400.0       509.0  37.0       1946.0  29.166667
# 21825  3000.0       760.0   0.0       3760.0  42.857143
#
# [21826 rows x 11 columns]

# %%
dados['Valor m2'] = dados['Valor m2'].round(2)

# %%
dados
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento              Cachambi        2      0       0    50
# ...            ...                   ...      ...    ...     ...   ...
# 21821  Apartamento                 Méier        2      0       0    70
# 21822    Quitinete                Centro        0      0       0    27
# 21823  Apartamento           Jacarepaguá        3      1       2    78
# 21824  Apartamento  São Francisco Xavier        2      1       0    48
# 21825  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU  Valor m2  Valor Bruto m2 Tipo Agregado
# 0      1700.0       500.0  60.0     42.50           56.50   Apartamento
# 1      7000.0         0.0   0.0     70.00           70.00          Casa
# 2       800.0       390.0  20.0     53.33           80.67   Apartamento
# 3       800.0       230.0   0.0     16.67           21.46   Apartamento
# 4      1300.0       301.0  17.0     26.00           32.36   Apartamento
# ...       ...         ...   ...       ...             ...           ...
# 21821   900.0       490.0  48.0     12.86           20.54   Apartamento
# 21822   800.0       350.0  25.0     29.63           43.52   Apartamento
# 21823  1800.0       800.0  40.0     23.08           33.85   Apartamento
# 21824  1400.0       509.0  37.0     29.17           40.54   Apartamento
# 21825  3000.0       760.0   0.0     42.86           53.71   Apartamento
#
# [21826 rows x 12 columns]

# %%
dados['Valor Bruto m2'] = (dados['Valor Bruto'] / dados['Area']).round(2)
dados
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento              Cachambi        2      0       0    50
# ...            ...                   ...      ...    ...     ...   ...
# 21821  Apartamento                 Méier        2      0       0    70
# 21822    Quitinete                Centro        0      0       0    27
# 21823  Apartamento           Jacarepaguá        3      1       2    78
# 21824  Apartamento  São Francisco Xavier        2      1       0    48
# 21825  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU  Valor Bruto  Valor m2  Valor Bruto m2
# 0      1700.0       500.0  60.0       2260.0     42.50           56.50
# 1      7000.0         0.0   0.0       7000.0     70.00           70.00
# 2       800.0       390.0  20.0       1210.0     53.33           80.67
# 3       800.0       230.0   0.0       1030.0     16.67           21.46
# 4      1300.0       301.0  17.0       1618.0     26.00           32.36
# ...       ...         ...   ...          ...       ...             ...
# 21821   900.0       490.0  48.0       1438.0     12.86           20.54
# 21822   800.0       350.0  25.0       1175.0     29.63           43.52
# 21823  1800.0       800.0  40.0       2640.0     23.08           33.85
# 21824  1400.0       509.0  37.0       1946.0     29.17           40.54
# 21825  3000.0       760.0   0.0       3760.0     42.86           53.71
#
# [21826 rows x 12 columns]

# %%
casa = ['Casa', 'Casa de Condomínio', 'Casa de Vila']

# %%
dados['Tipo Agregado'] = dados['Tipo'].apply(lambda x: 'Casa' if x in casa else 'Apartamento')

# %%
dados.sample(10)
# Out:
#                      Tipo                    Bairro  Quartos  Vagas  Suites  \
# 2302          Apartamento           Barra da Tijuca        3      2       1
# 12343  Casa de Condomínio           Barra da Tijuca        5      2       2
# 9502          Apartamento                     Irajá        2      1       1
# 2324          Apartamento  Recreio dos Bandeirantes        2      1       1
# 14349         Apartamento                   Ipanema        3      1       0
# 2949          Apartamento             Vila da Penha        2      0       0
# 18261         Apartamento                     Méier        1      1       0
# 3370          Apartamento           Jardim Botânico        3      0       0
# 17748         Apartamento              Campo Grande        2      1       0
# 15708         Apartamento                Copacabana        2      1       1
#
#        Area    Valor  Condominio   IPTU  Valor Bruto  Valor m2  \
# 2302    167   4500.0      2180.0  165.0       6845.0     26.95
# 12343   400  14000.0      2500.0    0.0      16500.0     35.00
# 9502     85   1500.0       295.0    0.0       1795.0     17.65
# 2324     74   1500.0      1247.0  190.0       2937.0     20.27
# 14349   114   3500.0      1511.0  296.0       5307.0     30.70
# 2949     52   1200.0       250.0    0.0       1450.0     23.08
# 18261    33    900.0       550.0   12.0       1462.0     27.27
# 3370    100   3300.0       730.0  209.0       4239.0     33.00
# 17748    50    850.0       340.0    0.0       1190.0     17.00
# 15708    93   3700.0       830.0  200.0       4730.0     39.78
#
#        Valor Bruto m2 Tipo Agregado
# 2302            40.99   Apartamento
# 12343           41.25          Casa
# 9502            21.12   Apartamento
# 2324            39.69   Apartamento
# 14349           46.55   Apartamento
# 2949            27.88   Apartamento
# 18261           44.30   Apartamento
# 3370            42.39   Apartamento
# 17748           23.80   Apartamento
# 15708           50.86   Apartamento

# %%
dados['Tipo Agregado'].value_counts()
# Out:
# Apartamento    19616
# Casa            2210
# Name: Tipo Agregado, dtype: int64

# %%
dados['Tipo'].value_counts()
# Out:
# Apartamento           18780
# Casa de Condomínio      996
# Casa                    965
# Quitinete               836
# Casa de Vila            249
# Name: Tipo, dtype: int64

# %%
dados.describe().round(2)
# Out:
#         Quartos     Vagas    Suites      Area       Valor  Condominio  \
# count  21826.00  21826.00  21826.00  21826.00    21826.00    21826.00
# mean       2.53      1.31      0.96    138.16     5046.17     1562.58
# std        1.09     13.32      1.14    146.92    32988.54    44514.90
# min        0.00      0.00      0.00     10.00      100.00        0.00
# 25%        2.00      0.00      0.00     65.00     1600.00      517.25
# 50%        2.00      1.00      1.00     90.00     2700.00      893.50
# 75%        3.00      2.00      1.00    155.00     5500.00     1542.00
# max       14.00   1960.00     14.00   3000.00  4500000.00  6552570.00
#
#             IPTU  Valor Bruto  Valor m2  Valor Bruto m2
# count   21826.00     21826.00  21826.00        21826.00
# mean      576.92      7185.67     35.85           52.87
# std      3832.09     55690.06    137.02          451.37
# min         0.00       100.00      2.78            2.78
# 25%         0.00      2229.25     21.12           30.07
# 50%       120.00      3900.00     29.97           43.01
# 75%       369.00      7600.00     42.00           58.63
# max    450625.00   6557025.00  15000.00        63048.32

# %%
dados.loc[dados['Valor'] == 4500000]
# Out:
#               Tipo    Bairro  Quartos  Vagas  Suites  Area      Valor  \
# 15520  Apartamento  Botafogo        4      1       1   300  4500000.0
#
#        Condominio  IPTU  Valor Bruto  Valor m2  Valor Bruto m2 Tipo Agregado
# 15520      1100.0   0.0    4501100.0   15000.0        15003.67   Apartamento

# %% [markdown]
# ## Excluindo Variaveis

# %%
dados_aux = pd.DataFrame(dados[['Tipo Agregado', 'Valor m2', 'Valor Bruto', 'Valor Bruto m2']])

# %%
dados_aux
# Out:
#       Tipo Agregado  Valor m2  Valor Bruto  Valor Bruto m2
# 0       Apartamento     42.50       2260.0           56.50
# 1              Casa     70.00       7000.0           70.00
# 2       Apartamento     53.33       1210.0           80.67
# 3       Apartamento     16.67       1030.0           21.46
# 4       Apartamento     26.00       1618.0           32.36
# ...             ...       ...          ...             ...
# 21821   Apartamento     12.86       1438.0           20.54
# 21822   Apartamento     29.63       1175.0           43.52
# 21823   Apartamento     23.08       2640.0           33.85
# 21824   Apartamento     29.17       1946.0           40.54
# 21825   Apartamento     42.86       3760.0           53.71
#
# [21826 rows x 4 columns]

# %%
del dados_aux['Valor Bruto']

# %%
dados_aux
# Out:
#       Tipo Agregado  Valor m2  Valor Bruto m2
# 0       Apartamento     42.50           56.50
# 1              Casa     70.00           70.00
# 2       Apartamento     53.33           80.67
# 3       Apartamento     16.67           21.46
# 4       Apartamento     26.00           32.36
# ...             ...       ...             ...
# 21821   Apartamento     12.86           20.54
# 21822   Apartamento     29.63           43.52
# 21823   Apartamento     23.08           33.85
# 21824   Apartamento     29.17           40.54
# 21825   Apartamento     42.86           53.71
#
# [21826 rows x 3 columns]

# %%
dados_aux.pop('Valor Bruto m2')
# Out:
# 0        56.50
# 1        70.00
# 2        80.67
# 3        21.46
# 4        32.36
#          ...
# 21821    20.54
# 21822    43.52
# 21823    33.85
# 21824    40.54
# 21825    53.71
# Name: Valor Bruto m2, Length: 21826, dtype: float64

# %%
dados_aux
# Out:
#       Tipo Agregado  Valor m2
# 0       Apartamento     42.50
# 1              Casa     70.00
# 2       Apartamento     53.33
# 3       Apartamento     16.67
# 4       Apartamento     26.00
# ...             ...       ...
# 21821   Apartamento     12.86
# 21822   Apartamento     29.63
# 21823   Apartamento     23.08
# 21824   Apartamento     29.17
# 21825   Apartamento     42.86
#
# [21826 rows x 2 columns]

# %%
dados.drop(['Valor Bruto', 'Valor Bruto m2'], axis = 1, inplace = True)
dados
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento              Cachambi        2      0       0    50
# ...            ...                   ...      ...    ...     ...   ...
# 21821  Apartamento                 Méier        2      0       0    70
# 21822    Quitinete                Centro        0      0       0    27
# 21823  Apartamento           Jacarepaguá        3      1       2    78
# 21824  Apartamento  São Francisco Xavier        2      1       0    48
# 21825  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU  Valor m2 Tipo Agregado
# 0      1700.0       500.0  60.0     42.50   Apartamento
# 1      7000.0         0.0   0.0     70.00          Casa
# 2       800.0       390.0  20.0     53.33   Apartamento
# 3       800.0       230.0   0.0     16.67   Apartamento
# 4      1300.0       301.0  17.0     26.00   Apartamento
# ...       ...         ...   ...       ...           ...
# 21821   900.0       490.0  48.0     12.86   Apartamento
# 21822   800.0       350.0  25.0     29.63   Apartamento
# 21823  1800.0       800.0  40.0     23.08   Apartamento
# 21824  1400.0       509.0  37.0     29.17   Apartamento
# 21825  3000.0       760.0   0.0     42.86   Apartamento
#
# [21826 rows x 11 columns]

# %%
dados.to_csv('dados/aluguel_residencial.csv', sep = ';', index = False)

# %%
# Nesta aula, aprendemos:

# Como criar variáveis
# Como excluir variáveis utilizando del, pop() e drop()
# Contadores, através do value_counts() e unique()
